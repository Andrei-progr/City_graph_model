# %%
import geopandas as gpd
import networkx as nx
import osmnx as ox
import shapely
import network_model
import folium

# %% [markdown]
# Инициализация сетевой модели. Загрузка геослоя с площадями и слоя с домами в класс

# %%
OPM_path = 'C:/Users/User/osm-spb/Vas_new.geojson'
house_path = 'C:/Users/User/osm-spb/House.geojson'

model = network_model.NetworkModel(OPM_path=OPM_path, house_path=house_path)
model.OPM
# Out:
#         id area_type    Тип Городская функция functional_type          area  \
# 0     1057     large   None              None                  17921.770684
# 1      229    medium   None              None                    695.402998
# 2      230     small   None              None                    219.378711
# 3      231     small   None              None                    391.590199
# 4      260     large   None              None                   1493.532095
# ..     ...       ...    ...               ...             ...           ...
# 367  14485     large    сад           Природа                  27483.440998
# 368  14486     large    сад           Природа                  28465.425935
# 369  14498     large    сад           Природа                  47407.178823
# 370  14550     large    сад           Природа                  16136.024783
# 371  14595     large  сквер           Природа                  25190.627339
#
#             exists                                           geometry
# 0    потенциальное  POLYGON ((30.23315 59.94747, 30.23367 59.94741...
# 1    потенциальное  POLYGON ((30.24831 59.95139, 30.24836 59.95127...
# 2    потенциальное  POLYGON ((30.24827 59.95094, 30.24819 59.95092...
# 3    потенциальное  POLYGON ((30.24856 59.95075, 30.24859 59.95065...
# 4    потенциальное  POLYGON ((30.23038 59.94712, 30.23047 59.94711...
# ..             ...                                                ...
# 367  потенциальное  POLYGON ((30.23906 59.92695, 30.23900 59.92697...
# 368  потенциальное  POLYGON ((30.24095 59.93385, 30.24256 59.93398...
# 369  потенциальное  POLYGON ((30.25417 59.93587, 30.25499 59.93610...
# 370  потенциальное  POLYGON ((30.28828 59.93796, 30.28825 59.93799...
# 371  потенциальное  POLYGON ((30.22041 59.93840, 30.22012 59.93843...
#
# [372 rows x 8 columns]

# %% [markdown]
# Поиск и классификация зеленых зон

# %%
model.find_exist('C:/Users/User/osm-spb/all_services.geojson')
model.OPM
# Out:
#         id area_type    Тип Городская функция      functional_type  \
# 0     1057     large   None              None
# 1      229    medium   None              None
# 2      230     small   None              None
# 3      231     small   None              None
# 4      260     large   None              None
# ..     ...       ...    ...               ...                  ...
# 367  14485     large    сад           Природа  Многофункциональное
# 368  14486     large    сад           Природа              Учебное
# 369  14498     large    сад           Природа           Спортивное
# 370  14550     large    сад           Природа           Событийное
# 371  14595     large  сквер           Природа           Спортивное
#
#              area         exists  \
# 0    17921.770684  потенциальное
# 1      695.402998  потенциальное
# 2      219.378711  потенциальное
# 3      391.590199  потенциальное
# 4     1493.532095  потенциальное
# ..            ...            ...
# 367  27483.440998   существующее
# 368  28465.425935   существующее
# 369  47407.178823   существующее
# 370  16136.024783   существующее
# 371  25190.627339   существующее
#
#                                               geometry
# 0    POLYGON ((30.23315 59.94747, 30.23367 59.94741...
# 1    POLYGON ((30.24831 59.95139, 30.24836 59.95127...
# 2    POLYGON ((30.24827 59.95094, 30.24819 59.95092...
# 3    POLYGON ((30.24856 59.95075, 30.24859 59.95065...
# 4    POLYGON ((30.23038 59.94712, 30.23047 59.94711...
# ..                                                 ...
# 367  POLYGON ((30.23906 59.92695, 30.23900 59.92697...
# 368  POLYGON ((30.24095 59.93385, 30.24256 59.93398...
# 369  POLYGON ((30.25417 59.93587, 30.25499 59.93610...
# 370  POLYGON ((30.28828 59.93796, 30.28825 59.93799...
# 371  POLYGON ((30.22041 59.93840, 30.22012 59.93843...
#
# [372 rows x 8 columns]

# %%
model.OPM[model.OPM['functional_type'] != '']
# Out:
#         id area_type    Тип Городская функция      functional_type  \
# 363  14314     large    сад           Природа  Многофункциональное
# 364  14405     large    сад           Природа           Событийное
# 366  14474     large    сад           Природа  Многофункциональное
# 367  14485     large    сад           Природа  Многофункциональное
# 368  14486     large    сад           Природа              Учебное
# 369  14498     large    сад           Природа           Спортивное
# 370  14550     large    сад           Природа           Событийное
# 371  14595     large  сквер           Природа           Спортивное
#
#              area        exists  \
# 363   7937.273900  существующее
# 364  13529.392360  существующее
# 366   8373.629664  существующее
# 367  27483.440998  существующее
# 368  28465.425935  существующее
# 369  47407.178823  существующее
# 370  16136.024783  существующее
# 371  25190.627339  существующее
#
#                                               geometry
# 363  POLYGON ((30.27213 59.94605, 30.27240 59.94613...
# 364  POLYGON ((30.29197 59.93882, 30.29214 59.93887...
# 366  POLYGON ((30.25950 59.94815, 30.25969 59.94820...
# 367  POLYGON ((30.23906 59.92695, 30.23900 59.92697...
# 368  POLYGON ((30.24095 59.93385, 30.24256 59.93398...
# 369  POLYGON ((30.25417 59.93587, 30.25499 59.93610...
# 370  POLYGON ((30.28828 59.93796, 30.28825 59.93799...
# 371  POLYGON ((30.22041 59.93840, 30.22012 59.93843...

# %% [markdown]
# Вызов метода для построения изохрон. На вход подается граф пешей доступности

# %%
model.create_isochrones('C:/Users/User/osm-spb/isohrone/walk_graph_spb_32636.graphml')
model.iso_5
# Out:
#         id area_type    Тип Городская функция      functional_type  \
# 0     1057     large   None              None
# 1      229    medium   None              None
# 2      230     small   None              None
# 3      231     small   None              None
# 4      260     large   None              None
# ..     ...       ...    ...               ...                  ...
# 367  14485     large    сад           Природа  Многофункциональное
# 368  14486     large    сад           Природа              Учебное
# 369  14498     large    сад           Природа           Спортивное
# 370  14550     large    сад           Природа           Событийное
# 371  14595     large  сквер           Природа           Спортивное
#
#              area         exists  \
# 0    17921.770684  потенциальное
# 1      695.402998  потенциальное
# 2      219.378711  потенциальное
# 3      391.590199  потенциальное
# 4     1493.532095  потенциальное
# ..            ...            ...
# 367  27483.440998   существующее
# 368  28465.425935   существующее
# 369  47407.178823   существующее
# 370  16136.024783   существующее
# 371  25190.627339   существующее
#
#                                               geometry    node
# 0    POLYGON ((30.23153 59.94345, 30.23047 59.94609...  189910
# 1    POLYGON ((30.24866 59.95032, 30.24764 59.95080...  271455
# 2    POLYGON ((30.24750 59.95012, 30.24612 59.95148...  236215
# 3    POLYGON ((30.24824 59.95013, 30.24796 59.95014...  274763
# 4    POLYGON ((30.22980 59.94480, 30.22926 59.94488...   50616
# ..                                                 ...     ...
# 367  POLYGON ((30.23897 59.92697, 30.23705 59.92956...   17693
# 368  POLYGON ((30.24194 59.93193, 30.24112 59.93345...   17573
# 369  POLYGON ((30.25821 59.93234, 30.25259 59.93289...   17616
# 370  POLYGON ((30.28879 59.93749, 30.28801 59.93791...  166699
# 371  POLYGON ((30.22122 59.93862, 30.22018 59.93873...   69974
#
# [372 rows x 9 columns]

# %% [markdown]
# Создание графа

# %%
g = model.create_graph()
g

# %%
model.OPM_info()
model.provision_info()
# Out:
# количество Многофункциональных ОП: 3
# количество Событийных ОП: 2
# количество Спортивных ОП: 2
# количество Учебных ОП: 1
# общее количество ОП: 8
# количество домов, обеспеченных многофункциональным типом: 518
# количество домов, обеспеченных событийным типом: 258
# количество домов, обеспеченных спортивным типом: 319
# количество домов, обеспеченных учебным типом: 175
# количество полностью обеспеченных домов: 0, общее количество домов: 1252
# Среднее время пути от домов до ОП 18.51 минуты

# %% [markdown]
# выбор одного оптимального места для ОПМ заданного размера и функционального типа, без открытия ОПМ в этом месте

# %%
a = model.best_location1('Событийное', 'medium')
print(f'id пространства: {a[1]}')
g.nodes[a[1]]
# Out:
# id пространства: 3150
# {'is_zone': True,
#  'area_type': 'medium',
#  'area': 978.5125976013051,
#  'functional_type': '',
#  'type': 'потенциальное',
#  'people_around': 281}

# %% [markdown]
# Вызов функций для нахождения полного решения. Сначала вызывается метод full_solution(), далее - local_search() для улучшения получившегося решения

# %%
model.full_solution()

# %%
model.local_search()

# %%
model.OPM_info()
model.provision_info()
# Out:
# количество Многофункциональных ОП: 16
# количество Событийных ОП: 17
# количество Спортивных ОП: 15
# количество Учебных ОП: 20
# общее количество ОП: 68
# количество домов, обеспеченных многофункциональным типом: 1001
# количество домов, обеспеченных событийным типом: 1179
# количество домов, обеспеченных спортивным типом: 971
# количество домов, обеспеченных учебным типом: 864
# количество полностью обеспеченных домов: 836, общее количество домов: 1252
# Среднее время пути от домов до ОП 11.53 минуты

# %% [markdown]
# Рекомендательная функция

# %%
model.recommend_services('Многофункциональное', 200)
# Out:
# 'Игровые зоны, Зелёные зоны, Общественный туалет, Музыкальное пространство, Учебная зона'

# %%
opm = model.geo()
opm
# Out:
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.OPM['functional_type'][indx] = self.graph.nodes[n]['functional_type']
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:570: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opm['ratio'][i] = self.get_ratio(row['functional_type'], row['area'])
# C:\Users\User\PycharmProjects\pythonProject2\network_model.py:572: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   opm['services'][i] = self.recommend_services(row['functional_type'], row['area'])
#         id      functional_type area_type          area  \
# 0     1057  Многофункциональное     large  17921.770684
# 2      230  Многофункциональное     small    219.378711
# 24     281              Учебное    medium   1020.396900
# 54    1010           Событийное    medium    633.492315
# 56    1055           Событийное     small    596.738371
# ..     ...                  ...       ...           ...
# 367  14485  Многофункциональное     large  27483.440998
# 368  14486              Учебное     large  28465.425935
# 369  14498           Спортивное     large  47407.178823
# 370  14550           Событийное     large  16136.024783
# 371  14595           Спортивное     large  25190.627339
#
#                                               geometry  \
# 0    POLYGON ((30.23315 59.94747, 30.23367 59.94741...
# 2    POLYGON ((30.24827 59.95094, 30.24819 59.95092...
# 24   POLYGON ((30.22213 59.94670, 30.22211 59.94666...
# 54   POLYGON ((30.26206 59.95162, 30.26241 59.95163...
# 56   POLYGON ((30.23956 59.94563, 30.23950 59.94568...
# ..                                                 ...
# 367  POLYGON ((30.23906 59.92695, 30.23900 59.92697...
# 368  POLYGON ((30.24095 59.93385, 30.24256 59.93398...
# 369  POLYGON ((30.25417 59.93587, 30.25499 59.93610...
# 370  POLYGON ((30.28828 59.93796, 30.28825 59.93799...
# 371  POLYGON ((30.22041 59.93840, 30.22012 59.93843...
#
#                                                  ratio  \
# 0    Отдых и общение: 9498.54 м^2, Обслуживание баз...
# 2    Отдых и общение: 116.27 м^2, Обслуживание базо...
# 24   Учебная: 612.24 м^2, Событийная: 102.04 м^2, О...
# 54   Событийная: 424.44 м^2, Обслуживание базовых п...
# 56   Событийная: 399.81 м^2, Обслуживание базовых п...
# ..                                                 ...
# 367  Отдых и общение: 14566.22 м^2, Обслуживание ба...
# 368  Учебная: 17079.26 м^2, Событийная: 2846.54 м^2...
# 369  Спортивная: 28444.31 м^2, Обслуживание базовых...
# 370  Событийная: 10811.14 м^2, Обслуживание базовых...
# 371  Спортивная: 15114.38 м^2, Обслуживание базовых...
#
#                                               services
# 0    Игровые зоны, Беседки, Зелёные зоны, Кафе, Фуд...
# 2    Игровые зоны, Зелёные зоны, Общественный туале...
# 24   Учебная зона, Лектории, Выставки, Сцена (амфит...
# 54   Сцена (амфитеатр), Кафе, Игровые зоны, Зелёные...
# 56   Сцена (амфитеатр), Кафе, Игровые зоны, Зелёные...
# ..                                                 ...
# 367  Игровые зоны, Беседки, Зелёные зоны, Кафе, Фуд...
# 368  Учебная зона, Лектории, Выставки, Сцена (амфит...
# 369  Универсальное спортивное поле, Скейтпарк, Спор...
# 370  Сцена (амфитеатр), Зона искусства, Музыкальное...
# 371  Универсальное спортивное поле, Скейтпарк, Спор...
#
# [68 rows x 7 columns]

# %%
m = folium.Map(location=[59.938732, 30.316229], zoom_start=10, tiles='CartoDB positron')
for i, r in opm.iterrows():
  sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
  geo_j = sim_geo.to_json()
  if r['functional_type'] == 'Многофункциональное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'blue'})
  if r['functional_type'] == 'Событийное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'red', 'color': 'red'})
  if r['functional_type'] == 'Спортивное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'green', 'color': 'green'})
  if r['functional_type'] == 'Учебное':
    geo_j = folium.GeoJson(data=geo_j,
                          style_function=lambda x: {'fillColor': 'yellow', 'color': 'yellow'})
  folium.Popup(r['ratio']).add_to(geo_j)
  geo_j.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ca3da0fbd428726cade3e052b1f61f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ca3da0fbd428726cade3e052b1f61f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5ca3da0fbd428726cade3e052b1f61f4 = L.map(
#                 &quot;map_5ca3da0fbd428726cade3e052b1f61f4&quot;,
#                 {
#                     center: [59.938732, 30.316229],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9c28ed2d1e847f4a4e07790fdf45909 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5ca3da0fbd428726cade3e052b1f61f4);
#
#
#         function geo_json_2870d89356fe5259aedabd0ee2081ea3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_2870d89356fe5259aedabd0ee2081ea3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2870d89356fe5259aedabd0ee2081ea3 = L.geoJson(null, {
#                 onEachFeature: geo_json_2870d89356fe5259aedabd0ee2081ea3_onEachFeature,
#
#                 style: geo_json_2870d89356fe5259aedabd0ee2081ea3_styler,
#         });
#
#         function geo_json_2870d89356fe5259aedabd0ee2081ea3_add (data) {
#             geo_json_2870d89356fe5259aedabd0ee2081ea3
#                 .addData(data)
#                 .addTo(map_5ca3da0fbd428726cade3e052b1f61f4);
#         }
#             geo_json_2870d89356fe5259aedabd0ee2081ea3_add({&quot;bbox&quot;: [30.23160741908857, 59.946718668356986, 30.237156076780675, 59.947468], &quot;features&quot;: [{&quot;bbox&quot;: [30.23160741908857, 59.946718668356986, 30.237156076780675, 59.947468], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.23315, 59.947468], [30.235235810699077, 59.947260086165976], [30.237156076780675, 59.946718668356986], [30.23160741908857, 59.947224844359916], [30.23315, 59.947468]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_0bf724aed03f86caa90ad365d6061c04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_252ac51845e85e79942aae1dec8b3ec9 = $(`&lt;div id=&quot;html_252ac51845e85e79942aae1dec8b3ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Отдых и общение: 9498.54 м^2, Обслуживание базовых потребностей: 896.09 м^2, Событийная: 1792.18 м^2, Спортивная: 3046.7 м^2, Учебная: 2688.27 м^2&lt;/div&gt;`)[0];
#                 popup_0bf724aed03f86caa90ad365d6061c04.setContent(html_252ac51845e85e79942aae1dec8b3ec9);
#
#
#
#         geo_json_2870d89356fe5259aedabd0ee2081ea3.bindPopup(popup_0bf724aed03f86caa90ad365d6061c04)
#         ;
#
#
#
#
#         function geo_json_02c22c4ae065751b919a3f847ddb6d2e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_02c22c4ae065751b919a3f847ddb6d2e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_02c22c4ae065751b919a3f847ddb6d2e = L.geoJson(null, {
#                 onEachFeature: geo_json_02c22c4ae065751b919a3f847ddb6d2e_onEachFeature,
#
#                 style: geo_json_02c22c4ae065751b919a3f847ddb6d2e_styler,
#         });
#
#         function geo_json_02c22c4ae065751b919a3f847ddb6d2e_add (data) {
#             geo_json_02c22c4ae065751b919a3f847ddb6d2e
#                 .addData(data)
#                 .addTo(map_5ca3da0fbd428726cade3e052b1f61f4);
#         }
#             geo_json_02c22c4ae065751b919a3f847ddb6d2e_add({&quot;bbox&quot;: [30.2482702, 59.950801283359624, 30.24853576646362, 59.9510019954357], &quot;features&quot;: [{&quot;bbox&quot;: [30.2482702, 59.950801283359624, 30.24853576646362, 59.9510019954357], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.2482702, 59.9509439], [30.24845855134155, 59.9510019954357], [30.24853576646362, 59.950801283359624], [30.248399600000013, 59.9508046], [30.2482702, 59.9509439]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_b32682be25b7afaf514916c2aa16dbc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3185382eebba26121ead9446b95918f3 = $(`&lt;div id=&quot;html_3185382eebba26121ead9446b95918f3&quot;
